# %%
import os
os.environ['USE_PYGEOS'] = '0'
import geopandas as gpd
import momepy as mm
import networkx as nx
from shapely import Point, LineString, reverse
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import itertools
from pyproj import Transformer
import datetime
import math

# %%
import functions as ft
import corrections as ct
from importlib import reload
reload(ft)
reload(ct)

#print the current date into the info.txt file
current_date = datetime.datetime.now().strftime("%d-%m-%Y %H:%M:%S")
ft.print_info(f"date: {current_date}")
# Out:
# date: 25-04-2023 00:40:39

# %% [markdown]
# ## 1. CREACIO DEL SubGraph
#
# Lectura geografica de la xarxa del 2021, creacio del Graph.
#
# Definim subGraph com la xarxa connectada a la depuradora.
#
# - no hi ha cap node/arc desconectat en el subGraph.
#
# - estem extraien tambe els sistemes de drenatge urba no connectats a la xarxa residual.
#
# Cal comprovar:
#
# - nodes sanitaris fora del subgraph?

# %%
# 1.  Introduim la xarxa completa en un Graph de NetworkX
node = gpd.read_file("data/networks/AdG_node.gpkg")
arc = gpd.read_file("data/networks/AdG_arc.gpkg")

# 1.1 creem un graph amb la xarxa
G = nx.DiGraph()
G.add_nodes_from([(row['node_id'], row) for index, row in node.iterrows() if row['state']!=0])
G.add_edges_from([(row['node_1'], row['node_2'], row) for index, row in arc.iterrows() if row['state']!=0])
# estem eliminant els obsolets escollint nomes els state=0 (OPERATIVO)

print('La xarxa OPERATIVA completa de 2021 conte: ')
print(f"nodes =  {len(G.nodes)}")
print(f"arcs = {len(G.edges)}")

#2. Extraiem la sub-xarxa connectada a la depuradora
#2.1 Definim la depuradora
edar_code= 'PR0005300'
edar,data_edar=[(node,data) for node, data in G.nodes(data=True) if data['code'] == edar_code][0]
data_edar['epa_type']="OUTFALL"
data_edar['sys_type']="OUTFALL"
data_edar['node_type']="OUTFALL"

#2.2 definim el subGraph associat:
G_notDi = nx.Graph(G)
subGraph = nx.DiGraph(nx.subgraph(G,nx.node_connected_component(G_notDi, edar)))

print('La xarxa connectada a la depuradora conte: ')
print(f"nodes =  {len(subGraph.nodes)}")
print(f"arcs = {len(subGraph.edges)}")
# Out:
# La xarxa OPERATIVA completa de 2021 conte:
# nodes =  13572
# arcs = 13682
# La xarxa connectada a la depuradora conte:
# nodes =  12017
# arcs = 12516

# %%
#3. Definim els elements de la nostra xarxa

# nodes marcats com OUTFALL
outfalls= [node for node, data in subGraph.nodes(data=True) if data['epa_type'] == 'OUTFALL']
print('nodes OUTFALL =', len(outfalls))

# nodes marcats com CHAMBERS
chambers= [node for node, data in subGraph.nodes(data=True) if data['nodecat_id'] == 'CEC' ]
print('nodes CHAMBER=', len(chambers))

# nodes marcats com CHAMBERS i son inici de xarxa
chambers_netinit= [node for node, data in subGraph.nodes(data=True) if data['nodecat_id'] == 'CEC' and subGraph.degree(node)==1]
print('nodes CHAMBER-NETINIT =', len(chambers_netinit))

# nodes marcats com MANHOLE
manholes= [node for node, data in subGraph.nodes(data=True) if data['sys_type'] == 'MANHOLE']
print('nodes MANHOLE =', len(manholes))

# arcs marcats com Sobreeixidor
sobreeixidors = [(node1, node2) for node1, node2, data in subGraph.edges(data=True) if data['category_type'] == 'Sobreeixidor']
print('arcs sobreeixidor (marcats) =', len(sobreeixidors))

sink = {node: data for node, data in subGraph.nodes(data=True) if subGraph.out_degree(node) == 0 and node!=edar and data['epa_type'] != 'OUTFALL'}
print('nodes direccionats cap a fora de la xarxa que no son outfall =', len(sink))

bad_chamber = {node: data for node, data in subGraph.nodes(data=True) if subGraph.degree(node) == 1 and node!=edar and data['nodecat_id'] =='CEC'}
print('camaras amb un sol arc:',len(bad_chamber))
# Out:
# nodes OUTFALL = 129
# nodes CHAMBER= 189
# nodes CHAMBER-NETINIT = 15
# nodes MANHOLE = 9811
# arcs sobreeixidor (marcats) = 278
# nodes direccionats cap a fora de la xarxa que no son outfall = 37
# camaras amb un sol arc: 15

# %% [markdown]
# ## 2. CORRECCIÓ DE LES DIRECCIONS
#
# 1. mirem, per tots els nodes, si van direccionats cap a la depuradora o un outfall/chamberNETINIT
#
# 2. Mentre hi hagi nodes que no arribin a la depuradora ni a un outfall
#
# - Per tots aquests nodes: Mirem si els seus veins arriben a la depuradora
#
# - Si algun vei arriba a la depuradora, afegim un nou arc que va del node al vei i eliminem l'antic
#
# - Si cap dels seus veins arriba a la depuradora, s'afegeix de nou a la llista  de nodes a revisar i es fa el loop

# %%
subGraph, malament, arcs_girats=ct.direccionament(subGraph,edar)


# REPORT: errors detectats en el direccionament
f = open("results/reports/report_direccions.txt", "w")
f.write(f"Nodes que no arriben a la depuradora = {len(malament)} \n")
for node in malament:
  f.write(str(subGraph.nodes[node]['code'])+",")
f.write(f"\n\nPer arreglar-los s'han canviat les direccions dels arcs = {len(arcs_girats)} \n")
for arc in arcs_girats:
  f.write(str(arc)+", ")
f.close()
# Out:
# nodes que no arriben a la depuradora = 891
# nodes que no arriben a la depuradora ni a un outfall ni a un chamberNETINIT = 69
# nodes que no arriben a la depuradora després del direccionament = 822
# nodes que no arriben a la depuradora ni a un outfall després del direccionament = 1

# %% [markdown]
# # 3. Correccio de les dades
#
# ### code:
#
# code erronis de nodes (no dels arcs), els corretgim com PRd'node_id'

# %%
# detectem els nodes amb code erroni 
nodes_amb_codi_erroni_21 =([node for node, data in G.nodes(data=True) if data['code'][0:2] != 'PR'])
print('nodes amb codi erroni = ( ', len(nodes_amb_codi_erroni_21), ' )')

# corregim el code dels nodes amb identificadoe incorrectes, guardem node_id a link
nodes_amb_codi_erroni =([node for node, data in subGraph.nodes(data=True) if data['code'][0:2] != 'PR'])
codi_PRd=[]
for node in nodes_amb_codi_erroni:
  data = subGraph.nodes[node]
  data['code'] = 'PRd' + str(data['node_id'] )
  codi_PRd = 'PRd' + str(data['node_id'] )

for node, data in subGraph.nodes(data=True):
  data['link'] = str(data['node_id'] )
# Out:
# nodes amb codi erroni = (  2334  )

# %% [markdown]
# ### top_elev
#
# opcio a)
#
# eliminem aquells valors que son nan o que estan fora del rang esperat (+-7 metres) del valor de altura obtingut pel raster geografic.
#
# omplim els valors desconeguts amb mitjana dels veins de primer ordre
#
# opcio b) [escollida]
#
# utilitzem la informacio geografica del raster
#
#                 qgis>toolbox>saple raster values

# %%
node_raster = gpd.read_file("data/subgraph_nodes_raster5m2020.gpkg")
nodes_erronis = []
jnan=0
jrang=0
for node, data in subGraph.nodes(data=True):
    z_raster=node_raster.loc[node_raster['code'] == data['code'], 'raster5m2020_1'].values[0]
    a=5
    if math.isnan(data['top_elev']):
        data['custom_top_elev'] = math.nan
        nodes_erronis.append(node)
        jnan=jnan+1
    if data['top_elev']>z_raster+a or data['top_elev']<z_raster-a:
        data['custom_top_elev'] = math.nan
        nodes_erronis.append(node)
        jrang=jrang+1
    else: 
        data['custom_top_elev'] = data['top_elev']

print(f"nodes amb top_elev fora del rang +-{a} metres = ({jrang}) i amb Nan ({jnan})")
print(f"nodes erronis inicials = {len(nodes_erronis)}")

# opcio de correccio a)  -------->  fem la mitjana dels veins de primer ordre
i = 0
while len(nodes_erronis) > 0:
    tmp = []
    for node_erroni in nodes_erronis:
        data_err = subGraph.nodes[node_erroni]
        first_neighbors = list(nx.all_neighbors(subGraph, node_erroni))
        costums_top_elev_neighbors = [data['custom_top_elev'] for node, data in subGraph.nodes(data=True) if node in first_neighbors and not math.isnan(data['custom_top_elev'])]
        if len(costums_top_elev_neighbors) > 0:
            data_err['custom_top_elev'] = np.mean(costums_top_elev_neighbors)
        else:
            tmp.append(node_erroni)
    i+=1
    nodes_erronis = tmp.copy()
    print('nodes_erronis a iteracio', i, ': ', len(nodes_erronis))


# opcio de correccio b) --------> fiquem custom_top_elev = z_raster
node_raster = gpd.read_file("data/subgraph_nodes_raster5m2020.gpkg")
for node, data in subGraph.nodes(data=True):
    z_raster=node_raster.loc[node_raster['code'] == data['code'], 'raster5m2020_1'].values[0]
    data['custom_top_elev'] = z_raster
# Out:
# nodes amb top_elev fora del rang +-5 metres = (98) i amb Nan (4405)
# nodes erronis inicials = 4503
# nodes_erronis a iteracio 1 :  1618
# nodes_erronis a iteracio 2 :  846
# nodes_erronis a iteracio 3 :  478
# nodes_erronis a iteracio 4 :  265
# nodes_erronis a iteracio 5 :  157
# nodes_erronis a iteracio 6 :  91
# nodes_erronis a iteracio 7 :  52
# nodes_erronis a iteracio 8 :  27
# nodes_erronis a iteracio 9 :  12
# nodes_erronis a iteracio 10 :  4
# nodes_erronis a iteracio 11 :  1
# nodes_erronis a iteracio 12 :  0

# %% [markdown]
# ### ymax
#
# comprovem valors fora del rang esperat (1, 10) metres i nan
#
# corrtegim amb mitjana dels veins

# %%
nodes_erronis = []
jnan=0
jrang=0
for node, data in subGraph.nodes(data=True):
    if math.isnan(data['ymax']):
        data['custom_ymax'] = math.nan
        nodes_erronis.append(node)
        jnan=jnan+1
    if data['ymax']<1 or data['ymax']>10:
        data['custom_ymax'] = math.nan
        nodes_erronis.append(node)
        jrang=jrang+1
    else: 
        data['custom_ymax'] = data['ymax']
print(f"nodes fora del rang (1,10) metres = ({jrang}) nodes amb Nan ({jnan})")
print('nodes erronis incials', len(nodes_erronis))

# fem la mitjana dels veins
i = 0
while len(nodes_erronis) > 0:
    tmp = []
    for node_erroni in nodes_erronis:
        data_err = subGraph.nodes[node_erroni]
        neighbors = list(nx.all_neighbors(subGraph, node_erroni))

        ymax_neighbors = [data['custom_ymax'] for node, data in subGraph.nodes(data=True) if node in neighbors and not math.isnan(data['custom_ymax'])]
        if len(ymax_neighbors) > 0:
            data_err['custom_ymax'] = np.mean(ymax_neighbors)
        else:
            tmp.append(node_erroni)
    i+=1
    nodes_erronis = tmp.copy()
    print('nodes_erronis a iteracio', i, ': ', len(nodes_erronis))
# Out:
# nodes fora del rang (1,10) metres = (1108) nodes amb Nan (2869)
# nodes erronis incials 3977
# nodes_erronis a iteracio 1 :  840
# nodes_erronis a iteracio 2 :  243
# nodes_erronis a iteracio 3 :  82
# nodes_erronis a iteracio 4 :  32
# nodes_erronis a iteracio 5 :  16
# nodes_erronis a iteracio 6 :  8
# nodes_erronis a iteracio 7 :  5
# nodes_erronis a iteracio 8 :  4
# nodes_erronis a iteracio 9 :  3
# nodes_erronis a iteracio 10 :  2
# nodes_erronis a iteracio 11 :  1
# nodes_erronis a iteracio 12 :  0

# %% [markdown]
# # 4. CORRECIO DE LES SLOPES
#
# Definim la llista de bombes per excloure de la correcio
#
# ALGORITHME DE SLOPES:
#
#     1. per tots els arcs, calculem slopes, les figuem en uns llista
#
#     2. si slope<0 de la llista: ajustem slope=0 i ajustem slopes dels veins (per actualitzar la llista)
#
#     3. apliquem loop sobre la llista mentre quedin slope<zero_slope* o fins a max_iterations
#         *(podem permetre un slope negatiu minim)
#
# insertem els valors corregits a custom_ymax, custom_y1, custom_y2

# %%
import corrections as correct
from importlib import reload
reload(correct)


# Definim la list de bombes ( arc_id values to remove)
arc_bombes_list = ['TR0002408','TR0050421','TR0006306','TR0022007']
# Make a copy of the original subGraph
subGraph_sense_bombes = subGraph.copy()
# Remove the edges with arc_id values in the list
for node1, node2, data in subGraph.edges(data=True):
    if data['code'] in arc_bombes_list:
        edge_to_remove = (node1, node2)
        subGraph_sense_bombes.remove_edge(*edge_to_remove)
print('arcs amb bombes =', len(subGraph.edges))
print('arcs sense bombes =', len(subGraph_sense_bombes.edges))


# Compute the initial slopes
zero_slope=0 # min slope alowed
neg_slope=0
#slopes_ini=pd.DataFrame(columns=['code', 'slope_ini','Delta_h_ini'])
slopes_ini=[]
for node1, node2, data in subGraph_sense_bombes.edges(data=True):
    data_node1 = subGraph_sense_bombes.nodes[node1]
    data_node2 = subGraph_sense_bombes.nodes[node2]
    elev1=data_node1['custom_top_elev']-data_node1['custom_ymax']
    elev2=data_node2['custom_top_elev']-data_node2['custom_ymax']
    Delta_h=(elev1-elev2)
    slope=(elev1-elev2)/data['gis_length']
    #slopes_ini = pd.concat([slopes_ini, pd.DataFrame({'code': [data['code']], 'slope_ini': [slope],'Delta_h_ini': [Delta_h]})], ignore_index=True)
    slopes_ini.append({'code': data['code'], 'slope_ini': slope,'Delta_h_ini': Delta_h})
    if slope<=zero_slope:
        neg_slope=neg_slope+1
slopes_ini = pd.DataFrame.from_records(slopes_ini)
slopes_ini.sort_values(by='slope_ini')
print(f"slopes negatives inicials ( {neg_slope} ), amb min = ( {min(slopes_ini['slope_ini'])} )")


# ALGORITHME DE SLOPES
# 1. per tots els arcs, calculem slopes, les figuem en uns llista
# 2. si slope<0 de la llista: ajustem slope=0 i ajustem slopes dels veins (per actualitzar la llista)
# 3. apliquem loop sobre la llista mentre quedin slope<zero_slope* o fins a max_iterations
# *(podem permetre un slope negatiu minim)

print("---- Slope correction ----")
new_ymax_sense_bombes,new_y1_y2_sense_bombes, slopes_corrected=correct.slopes(subGraph_sense_bombes,zero_slope=zero_slope,max_iteratons=200)

# comparem els resultats
slope_merged = pd.merge(slopes_ini, slopes_corrected, on='code').sort_values(by='slope_ini')
print("---- Resultats ----")
#print(slope_merged.head(5))

# insertem els valors corregits a custom_ymax
for node, data in subGraph.nodes(data=True):
    code = data['code']
    new_ymax_value = new_ymax_sense_bombes.loc[new_ymax_sense_bombes['code'] == code, 'new_ymax'].item()
    data['custom_ymax'] = new_ymax_value
    # correcio dels ymax negatuys: per error en precissio del raster
    if data['custom_ymax']<0:
        data['custom_top_elev']= data['custom_top_elev']+2*abs(data['custom_ymax'])
        data['custom_ymax']=abs(data['custom_ymax'])


# ajustem la profunditat de la boca dels arcs al valor 
for node1, node2, data in subGraph.edges(data=True):
    if data['code'] in new_y1_y2_sense_bombes['code']:
        data['custom_y1'] = new_y1_y2_sense_bombes.loc[new_y1_y2_sense_bombes['code'] == data['code']]['new_y1'].item()
        data['custom_y2'] = new_y1_y2_sense_bombes.loc[new_y1_y2_sense_bombes['code'] == data['code']]['new_y2'].item()
    else:
        data1=subGraph.nodes[node1]
        data2=subGraph.nodes[node2]
        data['custom_y1'] = data1['custom_ymax']
        data['custom_y2'] = data2['custom_ymax']
# Out:
# arcs amb bombes = 12516
# arcs sense bombes = 12512
# slopes negatives inicials ( 3025 ), amb min = ( -1.6259273670337826 )
# ---- Slope correction ----
# Iteració 0. Falten 3025 amb slope negatives amb min -1.6259273670337826
# Iteració 1. Falten 1296 amb slope negatives amb min -1.1715690786102706
# Iteració 2. Falten 1187 amb slope negatives amb min -0.6161962466769746
# Iteració 3. Falten 1006 amb slope negatives amb min -0.3968009345443222
# Iteració 4. Falten 833 amb slope negatives amb min -0.32967470721620823
# Iteració 5. Falten 706 amb slope negatives amb min -0.2902719873486173
# Iteració 6. Falten 630 amb slope negatives amb min -0.2591061810435728
# Iteració 7. Falten 535 amb slope negatives amb min -0.23384635406817766
# Iteració 8. Falten 483 amb slope negatives amb min -0.21248522495260191
# Iteració 9. Falten 437 amb slope negatives amb min -0.19386063644892224
# Iteració 10. Falten 394 amb slope negatives amb min -0.17731189188511412
# Iteració 11. Falten 369 amb slope negatives amb min -0.16241795150892985
# Iteració 12. Falten 334 amb slope negatives amb min -0.14888500038406358
# Iteració 13. Falten 316 amb slope negatives amb min -0.13649601616286805
# Iteració 14. Falten 299 amb slope negatives amb min -0.12508472701923803
# Iteració 15. Falten 280 amb slope negatives amb min -0.1145203845002708
# Iteració 16. Falten 257 amb slope negatives amb min -0.1076802365732323
# Iteració 17. Falten 234 amb slope negatives amb min -0.10157108757760736
# Iteració 18. Falten 214 amb slope negatives amb min -0.09579132076117441
# Iteració 19. Falten 202 amb slope negatives amb min -0.09020963596229463
# Iteració 20. Falten 185 amb slope negatives amb min -0.08478566509455043
# Iteració 21. Falten 176 amb slope negatives amb min -0.07951108029581719
# Iteració 22. Falten 164 amb slope negatives amb min -0.07438743443448072
# Iteració 23. Falten 156 amb slope negatives amb min -0.06941794543381996
# Iteració 24. Falten 142 amb slope negatives amb min -0.06460472281697156
# Iteració 25. Falten 133 amb slope negatives amb min -0.059948097610603414
# Iteració 26. Falten 124 amb slope negatives amb min -0.055446720639829236
# Iteració 27. Falten 117 amb slope negatives amb min -0.05109789593360988
# Iteració 28. Falten 112 amb slope negatives amb min -0.05078611169479491
# Iteració 29. Falten 104 amb slope negatives amb min -0.05091414964041543
# Iteració 30. Falten 97 amb slope negatives amb min -0.05101001475576758
# Iteració 31. Falten 88 amb slope negatives amb min -0.05108189531589523
# Iteració 32. Falten 83 amb slope negatives amb min -0.05113590940728922
# Iteració 33. Falten 78 amb slope negatives amb min -0.05117658011464602
# Iteració 34. Falten 74 amb slope negatives amb min -0.05120725784852202
# Iteració 35. Falten 68 amb slope negatives amb min -0.05123043406279141
# Iteració 36. Falten 72 amb slope negatives amb min -0.05124796800399139
# Iteració 37. Falten 62 amb slope negatives amb min -0.05126125086020879
# Iteració 38. Falten 66 amb slope negatives amb min -0.05127132583800807
# Iteració 39. Falten 61 amb slope negatives amb min -0.05127897665915103
# Iteració 40. Falten 59 amb slope negatives amb min -0.051284793093350406
# Iteració 41. Falten 60 amb slope negatives amb min -0.05128921964715584
# Iteració 42. Falten 55 amb slope negatives amb min -0.051292591832552754
# Iteració 43. Falten 53 amb slope negatives amb min -0.05129516324329859
# Iteració 44. Falten 51 amb slope negatives amb min -0.0512971258084985
# Iteració 45. Falten 47 amb slope negatives amb min -0.051298624969791026
# Iteració 46. Falten 44 amb slope negatives amb min -0.051299771073472576
# Iteració 47. Falten 46 amb slope negatives amb min -0.050623546294332585
# Iteració 48. Falten 43 amb slope negatives amb min -0.05087813076231399
# Iteració 49. Falten 41 amb slope negatives amb min -0.05137913210331369
# Iteració 50. Falten 35 amb slope negatives amb min -0.05132589752147649
# Iteració 51. Falten 31 amb slope negatives amb min -0.05202335485779514
# Iteració 52. Falten 32 amb slope negatives amb min -0.05174826204649298
# Iteració 53. Falten 31 amb slope negatives amb min -0.05250939191302742
# Iteració 54. Falten 32 amb slope negatives amb min -0.05208107397120582
# Iteració 55. Falten 27 amb slope negatives amb min -0.05286472112980172
# Iteració 56. Falten 26 amb slope negatives amb min -0.05232817749747959
# Iteració 57. Falten 21 amb slope negatives amb min -0.05304810214464727
# Iteració 58. Falten 21 amb slope negatives amb min -0.05246213168808449
# Iteració 59. Falten 16 amb slope negatives amb min -0.05293828854622442
# Iteració 60. Falten 16 amb slope negatives amb min -0.052412500225002386
# Iteració 61. Falten 12 amb slope negatives amb min -0.05153861281121178
# Iteració 62. Falten 13 amb slope negatives amb min -0.05242714128840332
# Iteració 63. Falten 10 amb slope negatives amb min -0.05128616595306632
# Iteració 64. Falten 12 amb slope negatives amb min -0.052414386853703455
# Iteració 65. Falten 11 amb slope negatives amb min -0.05110417706436757
# Iteració 66. Falten 10 amb slope negatives amb min -0.052348457274317445
# Iteració 67. Falten 11 amb slope negatives amb min -0.05091173793739139
# Iteració 68. Falten 8 amb slope negatives amb min -0.0520497734315857
# Iteració 69. Falten 10 amb slope negatives amb min -0.051777060785186416
# Iteració 70. Falten 9 amb slope negatives amb min -0.05095897237401828
# Iteració 71. Falten 10 amb slope negatives amb min -0.05198820540823992
# Iteració 72. Falten 9 amb slope negatives amb min -0.05083133460682732
# Iteració 73. Falten 8 amb slope negatives amb min -0.05200202192927067
# Iteració 74. Falten 10 amb slope negatives amb min -0.05173643677612647
# Iteració 75. Falten 9 amb slope negatives amb min -0.05212992257318
# Iteració 76. Falten 10 amb slope negatives amb min -0.05184164962173267
# Iteració 77. Falten 8 amb slope negatives amb min -0.05203806332483745
# Iteració 78. Falten 10 amb slope negatives amb min -0.051799616672048854
# Iteració 79. Falten 11 amb slope negatives amb min -0.05178586289634129
# Iteració 80. Falten 11 amb slope negatives amb min -0.05155925486343105
# Iteració 81. Falten 12 amb slope negatives amb min -0.05149475987183097
# Iteració 82. Falten 12 amb slope negatives amb min -0.051772700219183405
# Iteració 83. Falten 11 amb slope negatives amb min -0.05157144570273115
# Iteració 84. Falten 12 amb slope negatives amb min -0.052543844647812366
# Iteració 85. Falten 11 amb slope negatives amb min -0.051549832340106495
# Iteració 86. Falten 12 amb slope negatives amb min -0.05261515036782825
# Iteració 87. Falten 10 amb slope negatives amb min -0.0513512200728768
# Iteració 88. Falten 12 amb slope negatives amb min -0.052536928247258405
# Iteració 89. Falten 11 amb slope negatives amb min -0.051135995632533
# Iteració 90. Falten 11 amb slope negatives amb min -0.05122885736766409
# Iteració 91. Falten 12 amb slope negatives amb min -0.05215628111157123
# Iteració 92. Falten 11 amb slope negatives amb min -0.05127345953760533
# Iteració 93. Falten 12 amb slope negatives amb min -0.05235380713194999
# Iteració 94. Falten 11 amb slope negatives amb min -0.05115076776865429
# Iteració 95. Falten 13 amb slope negatives amb min -0.052356268878240526
# Iteració 96. Falten 13 amb slope negatives amb min -0.050978000293503446
# Iteració 97. Falten 13 amb slope negatives amb min -0.05221840998264082
# Iteració 98. Falten 14 amb slope negatives amb min -0.05188319866084382
# Iteració 99. Falten 13 amb slope negatives amb min -0.05227118509736496
# Iteració 100. Falten 14 amb slope negatives amb min -0.05194305011815057
# Iteració 101. Falten 13 amb slope negatives amb min -0.05091500867882441
# Iteració 102. Falten 14 amb slope negatives amb min -0.051993036589197336
# Iteració 103. Falten 16 amb slope negatives amb min -0.05069012065013313
# Iteració 104. Falten 14 amb slope negatives amb min -0.051863600885531935
# Iteració 105. Falten 15 amb slope negatives amb min -0.051645720511371826
# Iteració 106. Falten 14 amb slope negatives amb min -0.052021610842277285
# Iteració 107. Falten 15 amb slope negatives amb min -0.05176745146442553
# Iteració 108. Falten 14 amb slope negatives amb min -0.05184750143539796
# Iteració 109. Falten 14 amb slope negatives amb min -0.05164724463852359
# Iteració 110. Falten 15 amb slope negatives amb min -0.05270802526424195
# Iteració 111. Falten 14 amb slope negatives amb min -0.05170037258206395
# Iteració 112. Falten 15 amb slope negatives amb min -0.0516068714403697
# Iteració 113. Falten 14 amb slope negatives amb min -0.05157058415906332
# Iteració 114. Falten 15 amb slope negatives amb min -0.05149513056321069
# Iteració 115. Falten 15 amb slope negatives amb min -0.052499838076022404
# Iteració 116. Falten 15 amb slope negatives amb min -0.05156493801065794
# Iteració 117. Falten 14 amb slope negatives amb min -0.05261973411915872
# Iteració 118. Falten 15 amb slope negatives amb min -0.0512645756027103
# Iteració 119. Falten 14 amb slope negatives amb min -0.05247121108604433
# Iteració 120. Falten 16 amb slope negatives amb min -0.05206163902894872
# Iteració 121. Falten 14 amb slope negatives amb min -0.0513293565702994
# Iteració 122. Falten 15 amb slope negatives amb min -0.052245170732676066
# Iteració 123. Falten 15 amb slope negatives amb min -0.05100245680316308
# Iteració 124. Falten 15 amb slope negatives amb min -0.052173062311167924
# Iteració 125. Falten 16 amb slope negatives amb min -0.051857981872265584
# Iteració 126. Falten 16 amb slope negatives amb min -0.05226652497864532
# Iteració 127. Falten 15 amb slope negatives amb min -0.051936462245391925
# Iteració 128. Falten 15 amb slope negatives amb min -0.051975043327428354
# Iteració 129. Falten 15 amb slope negatives amb min -0.0517053533060274
# Iteració 130. Falten 16 amb slope negatives amb min -0.05276192686860346
# Iteració 131. Falten 16 amb slope negatives amb min -0.05171723307416048
# Iteració 132. Falten 15 amb slope negatives amb min -0.051622148108836856
# Iteració 133. Falten 16 amb slope negatives amb min -0.05150053375545134
# Iteració 134. Falten 14 amb slope negatives amb min -0.05136010117811074
# Iteració 135. Falten 16 amb slope negatives amb min -0.052417679094444315
# Iteració 136. Falten 16 amb slope negatives amb min -0.051427843210273175
# Iteració 137. Falten 16 amb slope negatives amb min -0.05252954359536685
# Iteració 138. Falten 17 amb slope negatives amb min -0.051096116764845684
# Iteració 139. Falten 16 amb slope negatives amb min -0.05225035043487409
# Iteració 140. Falten 17 amb slope negatives amb min -0.05191429785140666
# Iteració 141. Falten 17 amb slope negatives amb min -0.05113006359618849
# Iteració 142. Falten 15 amb slope negatives amb min -0.052106538531993096
# Iteració 143. Falten 17 amb slope negatives amb min -0.05076678071687573
# Iteració 144. Falten 16 amb slope negatives amb min -0.05187094732500216
# Iteració 145. Falten 17 amb slope negatives amb min -0.05165677313131613
# Iteració 146. Falten 16 amb slope negatives amb min -0.05199537584707834
# Iteració 147. Falten 17 amb slope negatives amb min -0.05171724119198922
# Iteració 148. Falten 17 amb slope negatives amb min -0.05272948241410357
# Iteració 149. Falten 16 amb slope negatives amb min -0.05169451809302583
# Iteració 150. Falten 17 amb slope negatives amb min -0.05276261339335835
# Iteració 151. Falten 18 amb slope negatives amb min -0.05131785435971428
# Iteració 152. Falten 18 amb slope negatives amb min -0.05128952090960337
# Iteració 153. Falten 19 amb slope negatives amb min -0.05221932173806709
# Iteració 154. Falten 19 amb slope negatives amb min -0.0512892959068009
# Iteració 155. Falten 19 amb slope negatives amb min -0.052378069349770434
# Iteració 156. Falten 22 amb slope negatives amb min -0.05093453657114577
# Iteració 157. Falten 20 amb slope negatives amb min -0.05203978182516041
# Iteració 158. Falten 19 amb slope negatives amb min -0.051772463626847565
# Iteració 159. Falten 20 amb slope negatives amb min -0.052108707197046696
# Iteració 160. Falten 20 amb slope negatives amb min -0.05176752500446469
# Iteració 161. Falten 23 amb slope negatives amb min -0.052792855552300205
# Iteració 162. Falten 21 amb slope negatives amb min -0.05172006957276909
# Iteració 163. Falten 21 amb slope negatives amb min -0.05162686413656142
# Iteració 164. Falten 24 amb slope negatives amb min -0.05892181842339488
# Iteració 165. Falten 22 amb slope negatives amb min -0.051263702927407236
# Iteració 166. Falten 22 amb slope negatives amb min -0.05235535762862021
# Iteració 167. Falten 21 amb slope negatives amb min -0.051325282713472205
# Iteració 168. Falten 21 amb slope negatives amb min -0.052417976287441354
# Iteració 169. Falten 22 amb slope negatives amb min -0.05201982060112421
# Iteració 170. Falten 21 amb slope negatives amb min -0.052397728788047965
# Iteració 171. Falten 22 amb slope negatives amb min -0.052030892321942926
# Iteració 172. Falten 23 amb slope negatives amb min -0.05199306128922746
# Iteració 173. Falten 23 amb slope negatives amb min -0.05163018581243226
# Iteració 174. Falten 24 amb slope negatives amb min -0.05155400705610655
# Iteració 175. Falten 23 amb slope negatives amb min -0.051758512035396415
# Iteració 176. Falten 24 amb slope negatives amb min -0.05154153592050131
# Iteració 177. Falten 23 amb slope negatives amb min -0.05253349493058278
# Iteració 178. Falten 22 amb slope negatives amb min -0.05152253443268916
# Iteració 179. Falten 25 amb slope negatives amb min -0.052601256214089606
# Iteració 180. Falten 24 amb slope negatives amb min -0.05112483448927222
# Iteració 181. Falten 24 amb slope negatives amb min -0.0522281100767147
# Iteració 182. Falten 25 amb slope negatives amb min -0.05190543437009434
# Iteració 183. Falten 25 amb slope negatives amb min -0.05706341392079552
# Iteració 184. Falten 25 amb slope negatives amb min -0.052831856620785746
# Iteració 185. Falten 24 amb slope negatives amb min -0.051755577790251465
# Iteració 186. Falten 23 amb slope negatives amb min -0.05789681401649906
# Iteració 187. Falten 23 amb slope negatives amb min -0.05181072704043532
# Iteració 188. Falten 25 amb slope negatives amb min -0.052770442153615704
# Iteració 189. Falten 24 amb slope negatives amb min -0.0517537711995531
# Iteració 190. Falten 24 amb slope negatives amb min -0.053806084013140756
# Iteració 191. Falten 26 amb slope negatives amb min -0.05248548585042773
# Iteració 192. Falten 23 amb slope negatives amb min -0.05124887087809997
# Iteració 193. Falten 24 amb slope negatives amb min -0.052189933266135434
# Iteració 194. Falten 25 amb slope negatives amb min -0.05827148309103159
# Iteració 195. Falten 24 amb slope negatives amb min -0.05227004248097693
# Iteració 196. Falten 25 amb slope negatives amb min -0.051923589170215945
# Iteració 197. Falten 24 amb slope negatives amb min -0.052269860734279326
# Iteració 198. Falten 25 amb slope negatives amb min -0.05193563072870028
# Iteració 199. Falten 27 amb slope negatives amb min -0.052894331237611156
# Iteració 200. Falten 24 amb slope negatives amb min -0.051839331293024316
# Iteració 201. Falten 24 amb slope negatives amb min -0.05287534311702417
# Iteració 202. Falten 26 amb slope negatives amb min -0.05136361814996119
# Iteració 203. Falten 23 amb slope negatives amb min -0.0520729247280781
# Iteració 204. Falten 24 amb slope negatives amb min -0.05221123794505972
# Iteració 205. Falten 25 amb slope negatives amb min -0.052348419558690414
# Iteració 206. Falten 23 amb slope negatives amb min -0.052224958804343934
# Iteració 207. Falten 25 amb slope negatives amb min -0.052243744468409986
# Iteració 208. Falten 24 amb slope negatives amb min -0.05343297768523386
# Iteració 209. Falten 27 amb slope negatives amb min -0.05789804923210795
# Iteració 210. Falten 26 amb slope negatives amb min -0.05362732595878567
# Iteració 211. Falten 25 amb slope negatives amb min -0.05485650588310771
# Iteració 212. Falten 25 amb slope negatives amb min -0.05434962805292322
# Iteració 213. Falten 25 amb slope negatives amb min -0.055031566155204124
# Iteració 214. Falten 24 amb slope negatives amb min -0.05624500738838635
# Iteració 215. Falten 26 amb slope negatives amb min -0.05570263625078706
# Iteració 216. Falten 26 amb slope negatives amb min -0.05636027394977535
# Iteració 217. Falten 25 amb slope negatives amb min -0.05755291796380222
# Iteració 218. Falten 28 amb slope negatives amb min -0.05697499373484636
# Iteració 219. Falten 26 amb slope negatives amb min -0.057612598613768454
# Iteració 220. Falten 27 amb slope negatives amb min -0.05878835898726372
# Iteració 221. Falten 28 amb slope negatives amb min -0.058179053879758795
# Iteració 222. Falten 31 amb slope negatives amb min -0.0587943528552304
# Iteració 223. Falten 32 amb slope negatives amb min -0.05994836033174241
# Iteració 224. Falten 33 amb slope negatives amb min -0.059306778706987494
# Iteració 225. Falten 35 amb slope negatives amb min -0.059901396403051685
# Iteració 226. Falten 36 amb slope negatives amb min -0.061040965496692225
# Iteració 227. Falten 34 amb slope negatives amb min -0.06157645274407485
# Iteració 228. Falten 37 amb slope negatives amb min -0.06245525217276239
# Iteració 229. Falten 38 amb slope negatives amb min -0.06357938879245459
# Iteració 230. Falten 36 amb slope negatives amb min -0.064035982181276
# Iteració 231. Falten 35 amb slope negatives amb min -0.06484422956246896
# Iteració 232. Falten 35 amb slope negatives amb min -0.06592606751458797
# Iteració 233. Falten 38 amb slope negatives amb min -0.06637753940325886
# Iteració 234. Falten 37 amb slope negatives amb min -0.06714036606873194
# Iteració 235. Falten 37 amb slope negatives amb min -0.066191906979751
# Iteració 236. Falten 37 amb slope negatives amb min -0.06649229989932337
# Iteració 237. Falten 38 amb slope negatives amb min -0.06738254473479871
# Iteració 238. Falten 37 amb slope negatives amb min -0.06772784068102596
# Iteració 239. Falten 37 amb slope negatives amb min -0.06844923421808108
# Iteració 240. Falten 37 amb slope negatives amb min -0.06944736174510242
# Iteració 241. Falten 38 amb slope negatives amb min -0.06980473982874251
# Iteració 242. Falten 37 amb slope negatives amb min -0.07048041385897315
# Iteració 243. Falten 38 amb slope negatives amb min -0.07140817707016918
# Iteració 244. Falten 37 amb slope negatives amb min -0.07169282402292514
# Iteració 245. Falten 38 amb slope negatives amb min -0.07229733570980315
# Iteració 246. Falten 36 amb slope negatives amb min -0.07117373809457486
# Iteració 247. Falten 39 amb slope negatives amb min -0.07133111403543398
# Iteració 248. Falten 37 amb slope negatives amb min -0.07209075367372354
# Iteració 249. Falten 35 amb slope negatives amb min -0.07230325659898523
# Iteració 250. Falten 37 amb slope negatives amb min -0.07291146211024635
# Iteració 251. Falten 36 amb slope negatives amb min -0.07380673857077477
# Iteració 252. Falten 39 amb slope negatives amb min -0.07405242773109866
# Iteració 253. Falten 36 amb slope negatives amb min -0.0746293043461779
# Iteració 254. Falten 37 amb slope negatives amb min -0.07546989758003134
# Iteració 255. Falten 38 amb slope negatives amb min -0.0756580274247509
# Iteració 256. Falten 38 amb slope negatives amb min -0.07617968295203079
# Iteració 257. Falten 39 amb slope negatives amb min -0.07696564239967203
# Iteració 258. Falten 37 amb slope negatives amb min -0.0770972142823094
# Iteració 259. Falten 38 amb slope negatives amb min -0.07756830855359823
# Iteració 260. Falten 38 amb slope negatives amb min -0.07749888384678523
# Iteració 261. Falten 37 amb slope negatives amb min -0.07784096508863984
# Iteració 262. Falten 39 amb slope negatives amb min -0.07850044133990303
# Iteració 263. Falten 38 amb slope negatives amb min -0.07854065494280439
# Iteració 264. Falten 38 amb slope negatives amb min -0.0789431698161758
# Iteració 265. Falten 37 amb slope negatives amb min -0.0796338860273551
# Iteració 266. Falten 37 amb slope negatives amb min -0.07968249566898929
# Iteració 267. Falten 37 amb slope negatives amb min -0.08008505963800551
# Falten 38 slope negatives, amb min -0.08076631069858704
#  --> slopes negatives finals = ( 38 ), amb min = ( 0.0 )
# ---- Resultats ----

# %%
slope_merged.sort_values(by='slope_final',ascending=False).head(10)
#pk Delta_h_corr dona constant?
# Out:
#             code  slope_ini  Delta_h_ini  slope_corr  Delta_h_corr  \
# 1459   TR0025166  -0.253962    -0.159996    0.003349       0.00211
# 503    TR0004515   0.318674     0.289993    0.002319       0.00211
# 12227  TR0020842   0.000000     0.000000    0.002638       0.00211
# 495    TR0011484   0.820000     0.820000    0.002110       0.00211
# 4925   TR0000838   0.221354     0.212500    0.002198       0.00211
# 5503   TR0023098   0.603779     0.640005    0.001991       0.00211
# 12071  TR0020739   0.160376     0.169998    0.001991       0.00211
# 281    TR0011643   0.000000     0.000000    0.002293       0.00211
# 1939   TR0024643   0.836961     1.540009    0.001147       0.00211
# 557    TR0011299   0.000000     0.000000    0.002110       0.00211
#
#        slope_final
# 1459          0.15
# 503           0.15
# 12227         0.15
# 495           0.15
# 4925          0.15
# 5503          0.15
# 12071         0.15
# 281           0.15
# 1939          0.15
# 557           0.15

# %% [markdown]
# ## 5. AJUST DE SOBREEIXIDORS
#
# definim arc de "sobreximent" com primer arc direccionats cap a un node que no es la depuradura.

# %%
# detectem arcs sobreeixidors
no_llegan_depuradora = [node for node in subGraph.nodes if not nx.has_path(subGraph, node, edar)]
node1_sobreeixidor = []
node2_sobreeixidor= []
for node in no_llegan_depuradora:
    veins=nx.all_neighbors(subGraph, node)
    for vei in veins:
        if nx.has_path(subGraph, vei, edar):
            node1_sobreeixidor.append(vei)
            node2_sobreeixidor.append(node)         
sobreeixidors_detected = [(node1, node2, data) for node1, node2, data in subGraph.edges(data=True) if  (data['node_1'] in node1_sobreeixidor) and (data['node_2'] in node2_sobreeixidor)]
sobreeixidors_marked = [(node1, node2, data) for node1, node2, data in subGraph.edges(data=True) if data['category_type'] == 'Sobreeixidor']

print('arcs detectats com sobreixidors = ',len(sobreeixidors_detected))
print('arcs marcats com sobreixidors = ',len(sobreeixidors_marked))


# corregim custom_y1 dels arcs sobreeixidors
sobreeixidors = sobreeixidors_detected
thresholds=[] #list de custom_y1 a modificar per afegir thresholds
b = 0.25  #altura extra
for node1, node2, data in sobreeixidors:
    in_edges = list(subGraph.in_edges(node1))
    out_edges = list(subGraph.out_edges(node1))
    out_edges = [(o, d) for o, d in out_edges if o!=node1 or d!=node2]

    # detectem la altura y_min del sobreiximent estimada (meitat del tub) i fem una llista de altures
    y_min = [] 
    for o, d in in_edges:
        data_in_edge = subGraph.edges[(o, d)]
        y_min.append(data_in_edge['custom_y2'] - data_in_edge['cat_geom1']/2)

    for o, d in out_edges:
        data_out_edge = subGraph.edges[(o, d)]
        y_min.append(data_out_edge['custom_y1'] - data_out_edge['cat_geom1']/2)
    
    
    data_node1 = subGraph.nodes[node1] # node sobreixidor
    threshold = np.min(y_min) - b  # ens quedem amb el valor mes petit de la llista i li substraiem b
    thresholds.append({'arc_code':data['code'],'custom_y1':data['custom_y1'],'custom_y1_threshold':threshold,'node1':data_node1['code'],'arcs_connect_to_node1':len(y_min)+1})
    subGraph.edges[(node1,node2)]['custom_y1'] = threshold  # update the value of custom_y1 with the threshold value
thresholds=pd.DataFrame.from_records(thresholds)


thresholds.sort_values(by='custom_y1_threshold',ascending=True).head(10)    
#thresholds[thresholds['arc_code'] == 'TR0003809']
# Out:
# arcs detectats com sobreixidors =  136
# arcs marcats com sobreixidors =  278
#       arc_code  custom_y1  custom_y1_threshold      node1  \
# 33   TR0050439   0.052499            -0.447501  PR0005319
# 68   TR0022828   0.647548             0.197548  PR0022033
# 83   TR0050138   0.813797             0.248797  PR0005630
# 86   TR0024982   0.839390             0.289390  PR0004440
# 0    TR0024972   1.900000             0.450000  PR0024351
# 127  TR0011149   0.922103             0.472103  PR0010728
# 4    TR0025822   0.940000             0.490000  PR0024353
# 71   TR0022590   0.980702             0.530702  PR0021841
# 65   TR0022839   0.935001             0.535001  PR0002665
# 3    TR0050500   0.991615             0.541615  PR0030062
#
#      arcs_connect_to_node1
# 33                       3
# 68                       3
# 83                       2
# 86                       5
# 0                        3
# 127                      3
# 4                        3
# 71                       2
# 65                       4
# 3                        3

# %%
for node1, node2, data in sobreeixidors:
    in_edges = list(subGraph.in_edges(node1))
    out_edges = list(subGraph.out_edges(node1))

    if data['code']=='TR0003809':
    
        print('code =', data['code'], 'custom_y1', data['custom_y1'], 'arc sobreixidor') 

    # detectem la altura dels tubs connectats al node 
    
        for o, d in in_edges:
            data_in_edge = subGraph.edges[(o, d)]
            print('code =', data_in_edge['code'], 'custom_y2', data_in_edge['custom_y2'])
        for o, d in out_edges:
            data_out_edge = subGraph.edges[(o, d)]
            print('code =', data_out_edge['code'], 'custom_y1', data_out_edge['custom_y1'])
# Out:
# code = TR0003809 custom_y1 2.0139420538036177 arc sobreixidor
# code = TR0003758 custom_y2 3.2639420538036177
# code = TR0003809 custom_y1 2.0139420538036177
# code = TR0050332 custom_y1 3.2639420538036177
# code = TR0003759 custom_y1 3.2639420538036177

# %%
# detectem els tubs que tenen y1+geom1 per sobre del terra i corregim

c=0.5
arc_y1_sobresortint=[]
arc_y2_sobresortint=[]
for node1, node2, data_arc in subGraph.edges(data=True):

    h1_arc=data_arc['custom_y1']-data_arc['cat_geom1']
    data_node1=subGraph.nodes[node1]
    in_edges1 = list(subGraph.in_edges(node1))
    out_edges1 = list(subGraph.out_edges(node1))
    if h1_arc<0:
        arc_y1_sobresortint.append({'arc_code':data['code'],'h1_arc':h1_arc})
        data_node1['custom_top_elev']=data_node1['custom_top_elev']+abs(h1_arc)+c
        data_node1['custom_ymax']= data_node1['custom_ymax']+abs(h1_arc)+c
        for o, d in in_edges1:
            data_in_edge1 = subGraph.edges[(o, d)]
            data_in_edge1['custom_y2']=data_in_edge1['custom_y2']+abs(h1_arc)+c
        for o, d in out_edges1:
            data_out_edge1 = subGraph.edges[(o, d)]
            data_out_edge1['custom_y1']=data_out_edge1['custom_y1']+abs(h1_arc)+c

    h2_arc=data_arc['custom_y2']-data_arc['cat_geom1']
    data_node2=subGraph.nodes[node2]
    in_edges2 = list(subGraph.in_edges(node2))
    out_edges2 = list(subGraph.out_edges(node2))
    if h2_arc<0:
        arc_y2_sobresortint.append({'arc_code':data['code'],'h2_arc':h2_arc})
        data_node2['custom_top_elev']=data_node2['custom_top_elev']+abs(h2_arc)+c
        data_node2['custom_ymax']= data_node2['custom_ymax']+abs(h2_arc)+c
        for o, d in in_edges2:
            data_in_edge2 = subGraph.edges[(o, d)]
            data_in_edge2['custom_y2']=data_in_edge2['custom_y2']+abs(h2_arc)+c
        for o, d in out_edges2:
            data_out_edge2 = subGraph.edges[(o, d)]
            data_out_edge2['custom_y1']=data_out_edge2['custom_y1']+abs(h2_arc)+c

print("arcs corregits que sobresurtien del terra per y1 = ", len(arc_y1_sobresortint))
print("arcs corregits que sobresurtien del terra per y2 = ", len(arc_y2_sobresortint))
# Out:
# arcs corregits que sobresurtien del terra per y1 =  47
# arcs corregits que sobresurtien del terra per y2 =  18

# %% [markdown]
# #### REPORT: errors detectats sobreeixidors

# %%
#els nodes de sobreiximent detectats  haurien de coiniceixin amb els marcats

# els nodes que no arriben a la depuradora
no_llegan_depuradora = [node for node in subGraph.nodes if not nx.has_path(subGraph, node, edar)]
# identifiquem els veins dels que no arriven i mirem si algun dells arriba a la depuradora 
# el vei que arribi sera el node 'pare' del sobreixidor
nodes_sobreeixidors = []
for node in no_llegan_depuradora:
    veins=nx.all_neighbors(subGraph, node)
    for vei in veins:
        if nx.has_path(subGraph, vei, edar):
            nodes_sobreeixidors.append(node)

print('nodes sobreeixidor detectats =',len(nodes_sobreeixidors))   


arcs_sobreeixidors_marcats = [(node1, node2, data) for node1, node2, data in subGraph.edges(data=True) if data['category_type'] == 'Sobreeixidor']
#print('arcs sobreeixidor marcats =',len(arcs_sobreeixidors_marcats))  

nodes_sobreeixidors_marcats = [node2 for node1, node2, data in arcs_sobreeixidors_marcats]
print('nodes sobreeixidor marcats =',len(nodes_sobreeixidors_marcats))

nodes_marcat_sobreeixidors_erronis=list(set(nodes_sobreeixidors_marcats)-set(nodes_sobreeixidors))

nodes_sobreeixidors_no_marcats=list(set(nodes_sobreeixidors)-set(nodes_sobreeixidors_marcats))


print('nodes marcats com a sobreeixidors que no ho son:', len(nodes_marcat_sobreeixidors_erronis))
print('nodes sobreeixidors detectat que no estan marcats:',len(nodes_sobreeixidors_no_marcats))
# Out:
# nodes sobreeixidor detectats = 136
# nodes sobreeixidor marcats = 278
# nodes marcats com a sobreeixidors que no ho son: 166
# nodes sobreeixidors detectat que no estan marcats: 26

# %%
# imprimim el report
f = open("results/reports/report_sobreeixidors.txt", "w")

f.write(f'nodes sobreeixidor detectats = {len(nodes_sobreeixidors)}\n')   
for node in nodes_sobreeixidors:
  f.write(str(subGraph.nodes[node]['code'])+",")

f.write(f'\n\nnodes marcats com a sobreeixidors que no ho son = {len(nodes_marcat_sobreeixidors_erronis)}\n')   
for node in nodes_marcat_sobreeixidors_erronis:
  f.write(str(subGraph.nodes[node]['code'])+",")

f.write(f'\n\nnodes sobreeixidors detectat que no estan marcats = {len(nodes_sobreeixidors_no_marcats)}\n')   
for node in nodes_sobreeixidors_no_marcats:
  f.write(str(subGraph.nodes[node]['code'])+",")

f.close()

# %% [markdown]
# ## 6. IMPRIMIR EL SUBGRAF CONNECTAT A LA DEPURADORA
#
# 1. diccionary     node_id_new,   node_id_old,   code: we  make a join between giswater_nodes and node with commun value code
# - giswater_nodes has an atribute called node_id that will be renamed as node_id_new
# - node has an atribute called node_id that will be renamed as node_id_old
#
# 2. impresio de .gpkg

# %%
#1.  canviem la nomenclatura de node_id en els nodes i node1, node2 dels arcs
# eliminem informacio inecessaria

# Load the GeoDataFrames
giswater_nodes=ft.download("AdG_2021", "subgraph.node")
# Rename the columns
giswater_nodes = giswater_nodes.rename(columns={'node_id': 'node_id_new'})
# Create a dictionary mapping codes to node IDs in giswater_nodes
code_to_node_id = dict(zip(giswater_nodes['code'], giswater_nodes['node_id_new']))

# use subgraph data to creat diccionary
dic_nodes = {}  
# Update dic_nodes with node_id_new information
for node, data in subGraph.nodes(data=True):
    node_id = data['node_id']
    code = data['code']
    node_id_new = code_to_node_id.get(code)
    if node_id_new is not None:
        dic_nodes[node] = {'node_id': node_id, 'node_id_new': node_id_new, 'code': code}
    else:
        print(f"No node with code '{code}' in giswater_nodes")


# update the node_id information in the subGraph 
for node, data in subGraph.nodes(data=True):
    # Get the 'node_id_new' value from the dictionary 'dic_nodes' using the 'code' attribute of the node
    node_info = dic_nodes.get(node)
    if node_info is not None:
        data['node_id'] = node_info['node_id_new']
    else:
        print(f"No information found for node '{node}'")

    # Set the value to NaN
    data['elev'] = np.nan
    data['custom_elev'] = np.nan
    data['sys_top_elev'] = np.nan
    data['sys_ymax'] = np.nan
    data['sys_elev'] = np.nan


# update the arc data information in the subGraph 
for node1, node2, data in subGraph.edges(data=True):
    # Get the 'node_id_new' value for 'node1' and 'node2' from the dictionary 'dic_nodes' using the 'code' attribute of the nodes
    node1_info = dic_nodes.get(node1)
    node2_info = dic_nodes.get(node2)
    if node1_info is not None and node2_info is not None:
        data['node_1'] = node1_info['node_id_new']
        data['node_2'] = node2_info['node_id_new']
    else:
        print(f"No information found for arc '{node1} - {node2}'")
    
    
    # Set the value to NaN

    data['r1'] = np.nan
    data['r2']=np.nan
    data['z1']=np.nan
    data['z2']=np.nan

    data['custom_elev1']=np.nan
    data['custom_elev2']=np.nan

    data['sys_elev1']=np.nan
    data['sys_elev2']=np.nan

    data['sys_y1']=np.nan
    data['sys_y2']=np.nan

    data['elev1']
    data['elev2']

    data['slope']=np.nan
    data['custom_length']=np.nan


print('done!')
# Out:
# done!

# %%
#2. imprimim el graph en un .gpkg per visualitzar en QGIS

#transformem les coordenades
transformer = Transformer.from_crs("EPSG:25831", "WGS84")

#afegim els nodes
for index, row in subGraph.nodes(data=True):
    if row['state'] != 0:
        x = row['geometry'].x
        y = row['geometry'].y

        long, lat = transformer.transform(x, y)
        row['longitude'] = long
        row['latitude'] = lat
        row['x'] = x
        row['y'] = y
        
        row['geometry'] = (lat, long)    

# fem una copia del subgraph i el reindexem amb la geometria dels nodes
subGraph_copy = subGraph.copy()
geometry_nodes = {node: data['geometry'] for node, data in subGraph_copy.nodes(data=True)}
subGraph_copy = nx.relabel_nodes(subGraph_copy, geometry_nodes)

# guardem el subgraph en dos .gpkg, un per nodes i un per arcs
points, lines = mm.nx_to_gdf(subGraph_copy)
points.set_geometry("geometry")
points.to_file("results/networks/nodes_corretgits_v2.gpkg", layer='nodes', driver="GPKG")
lines.set_geometry("geometry")

geometry= {}
for u, v, data in G.edges(data=True):
    geometry[u, v] = LineString((G.nodes[u]["geometry"],G.nodes[v]["geometry"]))
    nx.set_edge_attributes(G, geometry, "geometry")

lines.to_file("results/networks/arcs_corretgits_v2.gpkg", layer='arcs', driver="GPKG")
# Out:
# c:\Users\ruben\AppData\Local\Programs\Python\Python310\lib\site-packages\momepy\utils.py:430: UserWarning: Approach is not set. Defaulting to 'primal'.
#   warnings.warn("Approach is not set. Defaulting to 'primal'.")
